# %% [markdown]
# ## Notebook to scrape the needed data from the NSIDC 0630 database
# #### Looking to take 19 GHz (6.25km) and 37 GHz (3.125km) data from 1987 - 2011
# - Running this script downloads all the needed files from the directory for the 19Ghz (6.125km) and the 37Ghz (3.125km) Northern Hemishpere morning images
# - **It is important to remember that each sensor (F11,F13) are not available in every year
#     - If you intend to do many years, pay attention to which sensors you need for each time period

# %%
# %cd /Users/williamnorris/SWE_Clean/data
# Out:
# /Users/williamnorris/SWE_Clean/data

# %%
# %pylab notebook
import urllib2
import datetime
import subprocess
from subprocess import call
import shlex
import pandas as pd
import numpy as np
from pandas import datetime
from string import maketrans
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# **Sensor Years**
#
# **NOTE:** The Nimbus7 sensor did not record 19H. Is there an alternative? Or are those years hosed?
#
# - 1978: Not a full year of data
# - 1979: NIMBUS7 (pre Fx classification)
# - 1980: NIMBUS7
#     - Link Format: (https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/1980.01.01/NSIDC-0630-EASE2_S3.125km-NIMBUS7_SMMR-1980001-37H-M-SIR-JPL-v1.2.nc)
#
# - 1981: NIMBUS7
# - 1982: NIMBUS7
# - 1983: NIMBUS7
# - 1984: NIMBUS7
# - 1985: NIMBUS7
# - 1986: NIMBUS7
# - 1987: NIMBUS7
# - 1988: F08
#     - Link Format: (https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/1988.01.01/NSIDC-0630-EASE2_N6.25km-F08_SSMI-1988001-19H-M-SIR-CSU-v1.2.nc)
#
# - 1989: F08
# - 1990: F08
# - 1991: F08, F10 (F08 ends)
#
#     - F10 Link: (https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/1991.01.01/NSIDC-0630-EASE2_N25km-F10_SSMI-1991001-19H-M-GRD-CSU-v1.2.nc)
#
# - 1992: F10, F11 (F11 has ~20,000 less spikes per year)
#
#     - F11 Link: (https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/1992.01.01/NSIDC-0630-EASE2_N6.25km-F11_SSMI-1992001-19H-M-SIR-CSU-v1.2.nc)
#
# - 1993: F10, F11
# - 1994: F10, F11
# - 1995: F10, F11
# - 1996: F10, F11, F13 (F13 is best current sensor)
#     - F13 Link: (https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/1996.01.01/NSIDC-0630-EASE2_N6.25km-F13_SSMI-1996001-19H-M-SIR-CSU-v1.2.nc)
#
# - 1997: F10, F11, F13
# - 1998: F11, F13, F14
# - 1999: F11, F13, F14
# - 2000: F11, F13, F14
# - 2001: F13, F14, F15
#     - F15 Link: https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2001.01.01/NSIDC-0630-EASE2_N6.25km-F15_SSMI-2001001-19H-M-SIR-CSU-v1.2.nc
#
# - 2002: F13, F14, F15
# - 2003: F13, F14, F15, AQUA
# - 2004: F13, F14, F15, AQUA
# - 2005: F13, F14, F15, AQUA
# - 2006: F13, F14, F15, F16, AQUA
# - 2007: F13, F14, F15, F16, AQUA
# - 2008: F13, F14, F15, F16, AQUA
# - 2009: F13, F15, F16, F17, AQUA (F13 persists longer than F14)
# - 2010: F15, F16, F17, AQUA
# - 2011: F15, F16, F17, F18, AQUA (AQUA ends)
#     - F18 Link: https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.01.01/NSIDC-0630-EASE2_N6.25km-F18_SSMIS-2011001-19H-M-SIR-CSU-v1.2.nc
#
# - 2012: F15, F16, F17, F18
# - 2013: F15, F16, F17, F18
# - 2014: F15, F16, F17, F18
# - 2015: F15, F16, F17, F18, F19
# - 2016: Not a full year of data

# %% [markdown]
# $$ 1988:F08 \longrightarrow 1991:F10 \longrightarrow 1992:F11 \longrightarrow 1996:F13 \longrightarrow 2001:F15 \longrightarrow 2011:F18 $$

# %% [markdown]
# ### File Path Name Notes
#
# Things that change each year:
# - Sensor
# - Date range
# - SSMI vs SSMIS (year dependent)
# - resolution (37H = 3.125km, 19H = 6.25km)

# %% [markdown]
# # Web scraper for all NSIDC 0630 files
# ### Notes:
# #### - Follow instructions at [the NISDC's website]("https://nsidc.org/support/faq/what-options-are-available-bulk-downloading-data-https-earthdata-login-enabled") for instructions on setup

# %%
path = "/Users/williamnorris/SWE_Clean"
path19 = "/Users/williamnorris/SWE_Clean/data/19GHz_Wget"
path37 = "/Users/williamnorris/SWE_Clean/data/37GHz_Wget"

# %%
# function to make web scraping a piece of cake
def scrape(sensor, dates, dest19, dest37):
    # store the path of the url before the data (the date is updated on the fly)
    file_pre = 'https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/'
    if sensor in ['F16', 'F17', 'F18', 'F19']:
        post_19 = '/NSIDC-0630-EASE2_N6.25km-'+sensor+'_SSMIS-'
        last_19 = '-19H-M-SIR-CSU-v1.2.nc'
        post_37 = '/NSIDC-0630-EASE2_N3.125km-'+sensor+'_SSMIS-'
        last_37 = '-37H-M-SIR-CSU-v1.2.nc'
    else: 
        post_19 = '/NSIDC-0630-EASE2_N6.25km-'+sensor+'_SSMI-'
        last_19 = '-19H-M-SIR-CSU-v1.2.nc'
        post_37 = '/NSIDC-0630-EASE2_N3.125km-'+sensor+'_SSMI-'
        last_37 = '-37H-M-SIR-CSU-v1.2.nc'
    for date in dates: 
        # convert datetimeindex to date time
        temp = datetime.strptime(date, '%Y.%m.%d')
        # Store the year of the current date, convert to day of year
        year = temp.year
        temp = str(temp.timetuple().tm_yday)
        # pad front of day of year with zeroes to always be 3 char long
        temp = temp.rjust(3, '0')
        add = str(year)+temp
        # Combine constant file portions with dynamic portions 
        new_file_19 = file_pre + date + post_19 + add +last_19
        new_file_37 = file_pre + date + post_37 + add + last_37
        # Call wget on this file 
        cmd = 'wget -nd --load-cookies '+path+'/cookies.txt --save-cookies '+path+'/cookies.txt --keep-session-cookies --no-check-certificate --auth-no-challenge=on -r --reject "index.html*" -np -e robots=off -P '+path19+' '+new_file_19
        cmd2 = 'wget -nd --load-cookies '+path+'/cookies.txt --save-cookies '+path+'/cookies.txt --keep-session-cookies --no-check-certificate --auth-no-challenge=on -r --reject "index.html*" -np -e robots=off -P '+path37+' '+new_file_37
        print("Downloading the 19GHz and 37GHz files for: %s" % date)
        subprocess.call(shlex.split(cmd), shell = False)
        subprocess.call(shlex.split(cmd2), shell = False)
    print('Finished')

# %%
# Generate list of dates
start = datetime(2012, 1, 1)
end = datetime(2012, 12, 31)
dates = pd.date_range(start, end)

#convert time series to list of strings, translate '-' to '.' for URL
dates = dates.strftime('%Y.%m.%d')

sensor = 'F17'

scrape(sensor, dates, path19, path37)
# Out:
# Downloading the 19GHz and 37GHz files for: 2012.01.01
# Downloading the 19GHz and 37GHz files for: 2012.01.02
# Downloading the 19GHz and 37GHz files for: 2012.01.03
# Downloading the 19GHz and 37GHz files for: 2012.01.04
# Downloading the 19GHz and 37GHz files for: 2012.01.05
# Downloading the 19GHz and 37GHz files for: 2012.01.06
# Downloading the 19GHz and 37GHz files for: 2012.01.07
# Downloading the 19GHz and 37GHz files for: 2012.01.08
# Downloading the 19GHz and 37GHz files for: 2012.01.09
# Downloading the 19GHz and 37GHz files for: 2012.01.10
# Downloading the 19GHz and 37GHz files for: 2012.01.11
# Downloading the 19GHz and 37GHz files for: 2012.01.12
# Downloading the 19GHz and 37GHz files for: 2012.01.13
# Downloading the 19GHz and 37GHz files for: 2012.01.14
# Downloading the 19GHz and 37GHz files for: 2012.01.15
# Downloading the 19GHz and 37GHz files for: 2012.01.16
# Downloading the 19GHz and 37GHz files for: 2012.01.17
# Downloading the 19GHz and 37GHz files for: 2012.01.18
# Downloading the 19GHz and 37GHz files for: 2012.01.19
# Downloading the 19GHz and 37GHz files for: 2012.01.20
# Downloading the 19GHz and 37GHz files for: 2012.01.21
# Downloading the 19GHz and 37GHz files for: 2012.01.22
# Downloading the 19GHz and 37GHz files for: 2012.01.23
# Downloading the 19GHz and 37GHz files for: 2012.01.24
# Downloading the 19GHz and 37GHz files for: 2012.01.25
# Downloading the 19GHz and 37GHz files for: 2012.01.26
# Downloading the 19GHz and 37GHz files for: 2012.01.27
# Downloading the 19GHz and 37GHz files for: 2012.01.28
# Downloading the 19GHz and 37GHz files for: 2012.01.29
# Downloading the 19GHz and 37GHz files for: 2012.01.30
# Downloading the 19GHz and 37GHz files for: 2012.01.31
# Downloading the 19GHz and 37GHz files for: 2012.02.01
# Downloading the 19GHz and 37GHz files for: 2012.02.02
# Downloading the 19GHz and 37GHz files for: 2012.02.03
# Downloading the 19GHz and 37GHz files for: 2012.02.04
# Downloading the 19GHz and 37GHz files for: 2012.02.05
# Downloading the 19GHz and 37GHz files for: 2012.02.06
# Downloading the 19GHz and 37GHz files for: 2012.02.07
# Downloading the 19GHz and 37GHz files for: 2012.02.08
# Downloading the 19GHz and 37GHz files for: 2012.02.09
# Downloading the 19GHz and 37GHz files for: 2012.02.10
# Downloading the 19GHz and 37GHz files for: 2012.02.11
# Downloading the 19GHz and 37GHz files for: 2012.02.12
# Downloading the 19GHz and 37GHz files for: 2012.02.13
# Downloading the 19GHz and 37GHz files for: 2012.02.14
# Downloading the 19GHz and 37GHz files for: 2012.02.15
# Downloading the 19GHz and 37GHz files for: 2012.02.16
# Downloading the 19GHz and 37GHz files for: 2012.02.17
# Downloading the 19GHz and 37GHz files for: 2012.02.18
# Downloading the 19GHz and 37GHz files for: 2012.02.19
# Downloading the 19GHz and 37GHz files for: 2012.02.20
# Downloading the 19GHz and 37GHz files for: 2012.02.21
# Downloading the 19GHz and 37GHz files for: 2012.02.22
# Downloading the 19GHz and 37GHz files for: 2012.02.23
# Downloading the 19GHz and 37GHz files for: 2012.02.24
# Downloading the 19GHz and 37GHz files for: 2012.02.25
# Downloading the 19GHz and 37GHz files for: 2012.02.26
# Downloading the 19GHz and 37GHz files for: 2012.02.27
# Downloading the 19GHz and 37GHz files for: 2012.02.28
# Downloading the 19GHz and 37GHz files for: 2012.02.29
# Downloading the 19GHz and 37GHz files for: 2012.03.01
# Downloading the 19GHz and 37GHz files for: 2012.03.02
# Downloading the 19GHz and 37GHz files for: 2012.03.03
# Downloading the 19GHz and 37GHz files for: 2012.03.04
# Downloading the 19GHz and 37GHz files for: 2012.03.05
# Downloading the 19GHz and 37GHz files for: 2012.03.06
# Downloading the 19GHz and 37GHz files for: 2012.03.07
# Downloading the 19GHz and 37GHz files for: 2012.03.08
# Downloading the 19GHz and 37GHz files for: 2012.03.09
# Downloading the 19GHz and 37GHz files for: 2012.03.10
# Downloading the 19GHz and 37GHz files for: 2012.03.11
# Downloading the 19GHz and 37GHz files for: 2012.03.12
# Downloading the 19GHz and 37GHz files for: 2012.03.13
# Downloading the 19GHz and 37GHz files for: 2012.03.14
# Downloading the 19GHz and 37GHz files for: 2012.03.15
# Downloading the 19GHz and 37GHz files for: 2012.03.16
# Downloading the 19GHz and 37GHz files for: 2012.03.17
# Downloading the 19GHz and 37GHz files for: 2012.03.18
# Downloading the 19GHz and 37GHz files for: 2012.03.19
# Downloading the 19GHz and 37GHz files for: 2012.03.20
# Downloading the 19GHz and 37GHz files for: 2012.03.21
# Downloading the 19GHz and 37GHz files for: 2012.03.22
# Downloading the 19GHz and 37GHz files for: 2012.03.23
# Downloading the 19GHz and 37GHz files for: 2012.03.24
# Downloading the 19GHz and 37GHz files for: 2012.03.25
# Downloading the 19GHz and 37GHz files for: 2012.03.26
# Downloading the 19GHz and 37GHz files for: 2012.03.27
# Downloading the 19GHz and 37GHz files for: 2012.03.28
# Downloading the 19GHz and 37GHz files for: 2012.03.29
# Downloading the 19GHz and 37GHz files for: 2012.03.30
# Downloading the 19GHz and 37GHz files for: 2012.03.31
# Downloading the 19GHz and 37GHz files for: 2012.04.01
# Downloading the 19GHz and 37GHz files for: 2012.04.02
# Downloading the 19GHz and 37GHz files for: 2012.04.03
# Downloading the 19GHz and 37GHz files for: 2012.04.04
# Downloading the 19GHz and 37GHz files for: 2012.04.05
# Downloading the 19GHz and 37GHz files for: 2012.04.06
# Downloading the 19GHz and 37GHz files for: 2012.04.07
# Downloading the 19GHz and 37GHz files for: 2012.04.08
# Downloading the 19GHz and 37GHz files for: 2012.04.09
# Downloading the 19GHz and 37GHz files for: 2012.04.10
# Downloading the 19GHz and 37GHz files for: 2012.04.11
# Downloading the 19GHz and 37GHz files for: 2012.04.12
# Downloading the 19GHz and 37GHz files for: 2012.04.13
# Downloading the 19GHz and 37GHz files for: 2012.04.14
# Downloading the 19GHz and 37GHz files for: 2012.04.15
# Downloading the 19GHz and 37GHz files for: 2012.04.16
# Downloading the 19GHz and 37GHz files for: 2012.04.17
# Downloading the 19GHz and 37GHz files for: 2012.04.18
# Downloading the 19GHz and 37GHz files for: 2012.04.19
# Downloading the 19GHz and 37GHz files for: 2012.04.20
# Downloading the 19GHz and 37GHz files for: 2012.04.21
# Downloading the 19GHz and 37GHz files for: 2012.04.22
# Downloading the 19GHz and 37GHz files for: 2012.04.23
# Downloading the 19GHz and 37GHz files for: 2012.04.24
# Downloading the 19GHz and 37GHz files for: 2012.04.25
# Downloading the 19GHz and 37GHz files for: 2012.04.26
# Downloading the 19GHz and 37GHz files for: 2012.04.27
# Downloading the 19GHz and 37GHz files for: 2012.04.28
# Downloading the 19GHz and 37GHz files for: 2012.04.29
# Downloading the 19GHz and 37GHz files for: 2012.04.30
# Downloading the 19GHz and 37GHz files for: 2012.05.01
# Downloading the 19GHz and 37GHz files for: 2012.05.02
# Downloading the 19GHz and 37GHz files for: 2012.05.03
# Downloading the 19GHz and 37GHz files for: 2012.05.04
# Downloading the 19GHz and 37GHz files for: 2012.05.05
# Downloading the 19GHz and 37GHz files for: 2012.05.06
# Downloading the 19GHz and 37GHz files for: 2012.05.07
# Downloading the 19GHz and 37GHz files for: 2012.05.08
# Downloading the 19GHz and 37GHz files for: 2012.05.09
# Downloading the 19GHz and 37GHz files for: 2012.05.10
# Downloading the 19GHz and 37GHz files for: 2012.05.11
# Downloading the 19GHz and 37GHz files for: 2012.05.12
# Downloading the 19GHz and 37GHz files for: 2012.05.13
# Downloading the 19GHz and 37GHz files for: 2012.05.14
# Downloading the 19GHz and 37GHz files for: 2012.05.15
# Downloading the 19GHz and 37GHz files for: 2012.05.16
# Downloading the 19GHz and 37GHz files for: 2012.05.17
# Downloading the 19GHz and 37GHz files for: 2012.05.18
# Downloading the 19GHz and 37GHz files for: 2012.05.19
# Downloading the 19GHz and 37GHz files for: 2012.05.20
# Downloading the 19GHz and 37GHz files for: 2012.05.21
# Downloading the 19GHz and 37GHz files for: 2012.05.22
# Downloading the 19GHz and 37GHz files for: 2012.05.23
# Downloading the 19GHz and 37GHz files for: 2012.05.24
# Downloading the 19GHz and 37GHz files for: 2012.05.25
# Downloading the 19GHz and 37GHz files for: 2012.05.26
# Downloading the 19GHz and 37GHz files for: 2012.05.27
# Downloading the 19GHz and 37GHz files for: 2012.05.28
# Downloading the 19GHz and 37GHz files for: 2012.05.29
# Downloading the 19GHz and 37GHz files for: 2012.05.30
# Downloading the 19GHz and 37GHz files for: 2012.05.31
# Downloading the 19GHz and 37GHz files for: 2012.06.01
# Downloading the 19GHz and 37GHz files for: 2012.06.02
# Downloading the 19GHz and 37GHz files for: 2012.06.03
# Downloading the 19GHz and 37GHz files for: 2012.06.04
# Downloading the 19GHz and 37GHz files for: 2012.06.05
# Downloading the 19GHz and 37GHz files for: 2012.06.06
# Downloading the 19GHz and 37GHz files for: 2012.06.07
# Downloading the 19GHz and 37GHz files for: 2012.06.08
# Downloading the 19GHz and 37GHz files for: 2012.06.09
# Downloading the 19GHz and 37GHz files for: 2012.06.10
# Downloading the 19GHz and 37GHz files for: 2012.06.11
# Downloading the 19GHz and 37GHz files for: 2012.06.12
# Downloading the 19GHz and 37GHz files for: 2012.06.13
# Downloading the 19GHz and 37GHz files for: 2012.06.14
# Downloading the 19GHz and 37GHz files for: 2012.06.15
# Downloading the 19GHz and 37GHz files for: 2012.06.16
# Downloading the 19GHz and 37GHz files for: 2012.06.17
# Downloading the 19GHz and 37GHz files for: 2012.06.18
# Downloading the 19GHz and 37GHz files for: 2012.06.19
# Downloading the 19GHz and 37GHz files for: 2012.06.20
# Downloading the 19GHz and 37GHz files for: 2012.06.21
# Downloading the 19GHz and 37GHz files for: 2012.06.22
# Downloading the 19GHz and 37GHz files for: 2012.06.23
# Downloading the 19GHz and 37GHz files for: 2012.06.24
# Downloading the 19GHz and 37GHz files for: 2012.06.25
# Downloading the 19GHz and 37GHz files for: 2012.06.26
# Downloading the 19GHz and 37GHz files for: 2012.06.27
# Downloading the 19GHz and 37GHz files for: 2012.06.28
# Downloading the 19GHz and 37GHz files for: 2012.06.29
# Downloading the 19GHz and 37GHz files for: 2012.06.30
# Downloading the 19GHz and 37GHz files for: 2012.07.01
# Downloading the 19GHz and 37GHz files for: 2012.07.02
# Downloading the 19GHz and 37GHz files for: 2012.07.03
# Downloading the 19GHz and 37GHz files for: 2012.07.04
# Downloading the 19GHz and 37GHz files for: 2012.07.05
# Downloading the 19GHz and 37GHz files for: 2012.07.06
# Downloading the 19GHz and 37GHz files for: 2012.07.07
# Downloading the 19GHz and 37GHz files for: 2012.07.08
# Downloading the 19GHz and 37GHz files for: 2012.07.09
# Downloading the 19GHz and 37GHz files for: 2012.07.10
# Downloading the 19GHz and 37GHz files for: 2012.07.11
# Downloading the 19GHz and 37GHz files for: 2012.07.12
# Downloading the 19GHz and 37GHz files for: 2012.07.13
# Downloading the 19GHz and 37GHz files for: 2012.07.14
# Downloading the 19GHz and 37GHz files for: 2012.07.15
# Downloading the 19GHz and 37GHz files for: 2012.07.16
# Downloading the 19GHz and 37GHz files for: 2012.07.17
# Downloading the 19GHz and 37GHz files for: 2012.07.18
# Downloading the 19GHz and 37GHz files for: 2012.07.19
# Downloading the 19GHz and 37GHz files for: 2012.07.20
# Downloading the 19GHz and 37GHz files for: 2012.07.21
# Downloading the 19GHz and 37GHz files for: 2012.07.22
# Downloading the 19GHz and 37GHz files for: 2012.07.23
# Downloading the 19GHz and 37GHz files for: 2012.07.24
# Downloading the 19GHz and 37GHz files for: 2012.07.25
# Downloading the 19GHz and 37GHz files for: 2012.07.26
# Downloading the 19GHz and 37GHz files for: 2012.07.27
# Downloading the 19GHz and 37GHz files for: 2012.07.28
# Downloading the 19GHz and 37GHz files for: 2012.07.29
# Downloading the 19GHz and 37GHz files for: 2012.07.30
# Downloading the 19GHz and 37GHz files for: 2012.07.31
# Downloading the 19GHz and 37GHz files for: 2012.08.01
# Downloading the 19GHz and 37GHz files for: 2012.08.02
# Downloading the 19GHz and 37GHz files for: 2012.08.03
# Downloading the 19GHz and 37GHz files for: 2012.08.04
# Downloading the 19GHz and 37GHz files for: 2012.08.05
# Downloading the 19GHz and 37GHz files for: 2012.08.06
# Downloading the 19GHz and 37GHz files for: 2012.08.07
# Downloading the 19GHz and 37GHz files for: 2012.08.08
# Downloading the 19GHz and 37GHz files for: 2012.08.09
# Downloading the 19GHz and 37GHz files for: 2012.08.10
# Downloading the 19GHz and 37GHz files for: 2012.08.11
# Downloading the 19GHz and 37GHz files for: 2012.08.12
# Downloading the 19GHz and 37GHz files for: 2012.08.13
# Downloading the 19GHz and 37GHz files for: 2012.08.14
# Downloading the 19GHz and 37GHz files for: 2012.08.15
# Downloading the 19GHz and 37GHz files for: 2012.08.16
# Downloading the 19GHz and 37GHz files for: 2012.08.17
# Downloading the 19GHz and 37GHz files for: 2012.08.18
# Downloading the 19GHz and 37GHz files for: 2012.08.19
# Downloading the 19GHz and 37GHz files for: 2012.08.20
# Downloading the 19GHz and 37GHz files for: 2012.08.21
# Downloading the 19GHz and 37GHz files for: 2012.08.22
# Downloading the 19GHz and 37GHz files for: 2012.08.23
# Downloading the 19GHz and 37GHz files for: 2012.08.24
# Downloading the 19GHz and 37GHz files for: 2012.08.25
# Downloading the 19GHz and 37GHz files for: 2012.08.26
# Downloading the 19GHz and 37GHz files for: 2012.08.27
# Downloading the 19GHz and 37GHz files for: 2012.08.28
# Downloading the 19GHz and 37GHz files for: 2012.08.29
# Downloading the 19GHz and 37GHz files for: 2012.08.30
# Downloading the 19GHz and 37GHz files for: 2012.08.31
# Downloading the 19GHz and 37GHz files for: 2012.09.01
# Downloading the 19GHz and 37GHz files for: 2012.09.02
# Downloading the 19GHz and 37GHz files for: 2012.09.03
# Downloading the 19GHz and 37GHz files for: 2012.09.04
# Downloading the 19GHz and 37GHz files for: 2012.09.05
# Downloading the 19GHz and 37GHz files for: 2012.09.06
# Downloading the 19GHz and 37GHz files for: 2012.09.07
# Downloading the 19GHz and 37GHz files for: 2012.09.08
# Downloading the 19GHz and 37GHz files for: 2012.09.09
# Downloading the 19GHz and 37GHz files for: 2012.09.10
# Downloading the 19GHz and 37GHz files for: 2012.09.11
# Downloading the 19GHz and 37GHz files for: 2012.09.12
# Downloading the 19GHz and 37GHz files for: 2012.09.13
# Downloading the 19GHz and 37GHz files for: 2012.09.14
# Downloading the 19GHz and 37GHz files for: 2012.09.15
# Downloading the 19GHz and 37GHz files for: 2012.09.16
# Downloading the 19GHz and 37GHz files for: 2012.09.17
# Downloading the 19GHz and 37GHz files for: 2012.09.18
# Downloading the 19GHz and 37GHz files for: 2012.09.19
# Downloading the 19GHz and 37GHz files for: 2012.09.20
# Downloading the 19GHz and 37GHz files for: 2012.09.21
# Downloading the 19GHz and 37GHz files for: 2012.09.22
# Downloading the 19GHz and 37GHz files for: 2012.09.23
# Downloading the 19GHz and 37GHz files for: 2012.09.24
# Downloading the 19GHz and 37GHz files for: 2012.09.25
# Downloading the 19GHz and 37GHz files for: 2012.09.26
# Downloading the 19GHz and 37GHz files for: 2012.09.27
# Downloading the 19GHz and 37GHz files for: 2012.09.28
# Downloading the 19GHz and 37GHz files for: 2012.09.29
# Downloading the 19GHz and 37GHz files for: 2012.09.30
# Downloading the 19GHz and 37GHz files for: 2012.10.01
# Downloading the 19GHz and 37GHz files for: 2012.10.02
# Downloading the 19GHz and 37GHz files for: 2012.10.03
# Downloading the 19GHz and 37GHz files for: 2012.10.04
# Downloading the 19GHz and 37GHz files for: 2012.10.05
# Downloading the 19GHz and 37GHz files for: 2012.10.06
# Downloading the 19GHz and 37GHz files for: 2012.10.07
# Downloading the 19GHz and 37GHz files for: 2012.10.08
# Downloading the 19GHz and 37GHz files for: 2012.10.09
# Downloading the 19GHz and 37GHz files for: 2012.10.10
# Downloading the 19GHz and 37GHz files for: 2012.10.11
# Downloading the 19GHz and 37GHz files for: 2012.10.12
# Downloading the 19GHz and 37GHz files for: 2012.10.13
# Downloading the 19GHz and 37GHz files for: 2012.10.14
# Downloading the 19GHz and 37GHz files for: 2012.10.15
# Downloading the 19GHz and 37GHz files for: 2012.10.16
# Downloading the 19GHz and 37GHz files for: 2012.10.17
# Downloading the 19GHz and 37GHz files for: 2012.10.18
# Downloading the 19GHz and 37GHz files for: 2012.10.19
# Downloading the 19GHz and 37GHz files for: 2012.10.20
# Downloading the 19GHz and 37GHz files for: 2012.10.21
# Downloading the 19GHz and 37GHz files for: 2012.10.22
# Downloading the 19GHz and 37GHz files for: 2012.10.23
# Downloading the 19GHz and 37GHz files for: 2012.10.24
# Downloading the 19GHz and 37GHz files for: 2012.10.25
# Downloading the 19GHz and 37GHz files for: 2012.10.26
# Downloading the 19GHz and 37GHz files for: 2012.10.27
# Downloading the 19GHz and 37GHz files for: 2012.10.28
# Downloading the 19GHz and 37GHz files for: 2012.10.29
# Downloading the 19GHz and 37GHz files for: 2012.10.30
# Downloading the 19GHz and 37GHz files for: 2012.10.31
# Downloading the 19GHz and 37GHz files for: 2012.11.01
# Downloading the 19GHz and 37GHz files for: 2012.11.02
# Downloading the 19GHz and 37GHz files for: 2012.11.03
# Downloading the 19GHz and 37GHz files for: 2012.11.04
# Downloading the 19GHz and 37GHz files for: 2012.11.05
# Downloading the 19GHz and 37GHz files for: 2012.11.06
# Downloading the 19GHz and 37GHz files for: 2012.11.07
# Downloading the 19GHz and 37GHz files for: 2012.11.08
# Downloading the 19GHz and 37GHz files for: 2012.11.09
# Downloading the 19GHz and 37GHz files for: 2012.11.10
# Downloading the 19GHz and 37GHz files for: 2012.11.11
# Downloading the 19GHz and 37GHz files for: 2012.11.12
# Downloading the 19GHz and 37GHz files for: 2012.11.13
# Downloading the 19GHz and 37GHz files for: 2012.11.14
# Downloading the 19GHz and 37GHz files for: 2012.11.15
# Downloading the 19GHz and 37GHz files for: 2012.11.16
# Downloading the 19GHz and 37GHz files for: 2012.11.17
# Downloading the 19GHz and 37GHz files for: 2012.11.18
# Downloading the 19GHz and 37GHz files for: 2012.11.19
# Downloading the 19GHz and 37GHz files for: 2012.11.20
# Downloading the 19GHz and 37GHz files for: 2012.11.21
# Downloading the 19GHz and 37GHz files for: 2012.11.22
# Downloading the 19GHz and 37GHz files for: 2012.11.23
# Downloading the 19GHz and 37GHz files for: 2012.11.24
# Downloading the 19GHz and 37GHz files for: 2012.11.25
# Downloading the 19GHz and 37GHz files for: 2012.11.26
# Downloading the 19GHz and 37GHz files for: 2012.11.27
# Downloading the 19GHz and 37GHz files for: 2012.11.28
# Downloading the 19GHz and 37GHz files for: 2012.11.29
# Downloading the 19GHz and 37GHz files for: 2012.11.30
# Downloading the 19GHz and 37GHz files for: 2012.12.01
# Downloading the 19GHz and 37GHz files for: 2012.12.02
# Downloading the 19GHz and 37GHz files for: 2012.12.03
# Downloading the 19GHz and 37GHz files for: 2012.12.04
# Downloading the 19GHz and 37GHz files for: 2012.12.05
# Downloading the 19GHz and 37GHz files for: 2012.12.06
# Downloading the 19GHz and 37GHz files for: 2012.12.07
# Downloading the 19GHz and 37GHz files for: 2012.12.08
# Downloading the 19GHz and 37GHz files for: 2012.12.09
# Downloading the 19GHz and 37GHz files for: 2012.12.10
# Downloading the 19GHz and 37GHz files for: 2012.12.11
# Downloading the 19GHz and 37GHz files for: 2012.12.12
# Downloading the 19GHz and 37GHz files for: 2012.12.13
# Downloading the 19GHz and 37GHz files for: 2012.12.14
# Downloading the 19GHz and 37GHz files for: 2012.12.15
# Downloading the 19GHz and 37GHz files for: 2012.12.16
# Downloading the 19GHz and 37GHz files for: 2012.12.17
# Downloading the 19GHz and 37GHz files for: 2012.12.18
# Downloading the 19GHz and 37GHz files for: 2012.12.19
# Downloading the 19GHz and 37GHz files for: 2012.12.20
# Downloading the 19GHz and 37GHz files for: 2012.12.21
# Downloading the 19GHz and 37GHz files for: 2012.12.22
# Downloading the 19GHz and 37GHz files for: 2012.12.23
# Downloading the 19GHz and 37GHz files for: 2012.12.24
# Downloading the 19GHz and 37GHz files for: 2012.12.25
# Downloading the 19GHz and 37GHz files for: 2012.12.26
# Downloading the 19GHz and 37GHz files for: 2012.12.27
# Downloading the 19GHz and 37GHz files for: 2012.12.28
# Downloading the 19GHz and 37GHz files for: 2012.12.29
# Downloading the 19GHz and 37GHz files for: 2012.12.30
# Downloading the 19GHz and 37GHz files for: 2012.12.31
# Finished

# %% [markdown]
# ## The following is old, non-modular code

# %%
# store the path of the url before the data (the date is updated on the fly)
file_pre = 'https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/'
# store the path of the url after the date
file_post = '/NSIDC-0630-EASE2_N6.25km-F08_SSMI-'
file_last = '-19H-M-SIR-CSU-v1.2.nc'


post_37 = '/NSIDC-0630-EASE2_N3.125km-F08_SSMI-'
last_37 = '-37H-M-SIR-CSU-v1.2.nc'

# %%
# Generate list of dates
start = datetime(1988, 1, 1)
end = datetime(1988, 12, 31)
dates = pd.date_range(start, end)

#convert time series to list of strings, translate '-' to '.' for URL
dates = dates.strftime('%Y.%m.%d')

# %%
# For loop to generate all the file names and download on the fly!
for date in dates: 
    # convert datetimeindex to date time
    temp = datetime.strptime(date, '%Y.%m.%d')
    # Store the year of the current date, convert to day of year
    year = temp.year
    temp = str(temp.timetuple().tm_yday)
    # pad front of day of year with zeroes to alwasy be 3 char long
    temp = temp.rjust(3, '0')
    add = str(year)+temp
    # Combine constant file portions with dynamic portions 
    new_file = file_pre + date + file_post + add +file_last
    new_file_37 = file_pre + date + post_37 + add + last_37
    # Call wget on this file 
    cmd = 'wget -nd --load-cookies '+path+'/cookies.txt --save-cookies '+path+'/cookies.txt --keep-session-cookies --no-check-certificate --auth-no-challenge=on -r --reject "index.html*" -np -e robots=off -P '+path19+' '+new_file
    cmd2 = 'wget -nd --load-cookies '+path+'/cookies.txt --save-cookies '+path+'/cookies.txt --keep-session-cookies --no-check-certificate --auth-no-challenge=on -r --reject "index.html*" -np -e robots=off -P '+path37+' '+new_file_37
    print("Downloading the 19GHz and 37GHz files for: %s" % date)
    subprocess.call(shlex.split(cmd), shell = False)
    subprocess.call(shlex.split(cmd2), shell = False)
print('Finished')

# %%
# convert web scraping script to funciton for automation **work in progress** 
def scrape(sensor, dates, dest19, dest37):
    # store the path of the url before the data (the date is updated on the fly)
    file_pre = 'https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/'
    file_post = '/NSIDC-0630-EASE2_N6.25km-'+sensor+'_SSMI-'
    file_last = '-19H-M-SIR-CSU-v1.2.nc'
    
    post_37 = '/NSIDC-0630-EASE2_N3.125km-'+sensor+'_SSMI-'
    last_37 = '-37H-M-SIR-CSU-v1.2.nc'
    for date in dates: 
        # convert datetimeindex to date time
        temp = datetime.strptime(date, '%Y.%m.%d')
        # Store the year of the current date, convert to day of year
        year = temp.year
        temp = str(temp.timetuple().tm_yday)
        # pad front of day of year with zeroes to always be 3 char long
        temp = temp.rjust(3, '0')
        add = str(year)+temp
        # Combine constant file portions with dynamic portions 
        new_file = file_pre + date + file_post + add +file_last
        new_file_37 = file_pre + date + post_37 + add + last_37
        # Call wget on this file 
        cmd = 'wget -nd --load-cookies '+path+'/cookies.txt --save-cookies '+path+'/cookies.txt --keep-session-cookies --no-check-certificate --auth-no-challenge=on -r --reject "index.html*" -np -e robots=off -P '+path19+' '+new_file
        cmd2 = 'wget -nd --load-cookies '+path+'/cookies.txt --save-cookies '+path+'/cookies.txt --keep-session-cookies --no-check-certificate --auth-no-challenge=on -r --reject "index.html*" -np -e robots=off -P '+path37+' '+new_file_37
        print("Downloading the 19GHz and 37GHz files for: %s" % date)
        subprocess.call(shlex.split(cmd), shell = False)
        subprocess.call(shlex.split(cmd2), shell = False)
    print('Finished')

# %%
# Generate list of dates
start = datetime(1988, 1, 1)
end = datetime(1988, 12, 31)
dates = pd.date_range(start, end)

#convert time series to list of strings, translate '-' to '.' for URL
dates = dates.strftime('%Y.%m.%d')

sensor = 'F08'

scrape(sensor, dates, path19, path37)
